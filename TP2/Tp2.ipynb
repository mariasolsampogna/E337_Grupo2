# %%
### Parte I:

# %%
#Importamos paquetes
import pandas as pd
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Directorio Lucas:

os.chdir(r"C:\Users\Gaelj\OneDrive\Documentos\Universidad San Andres\4° Año\Big Data\Tp2")

# %%
### Ejercicio 1:

# Para este ejercicio, necesitamos traer la base de datos "limpiada" del trabajo práctico anterior. Esto lo hicimos usando .to_parquet para descargar las bases como dta

df = pd.read_parquet("base_con_informal")

# %%
df.columns
# Out:
# Index(['CH04', 'CH06', 'CH07', 'CH08', 'NIVEL_ED', 'ESTADO', 'CAT_INAC',
#        'IPCF', 'CH14', 'CH15_COD', 'CH16_COD', 'PP03C', 'PP04B_COD', 'PP06H',
#        'PP07A', 'AÑO', 'CAT_OCUP', 'PP07H', 'informal', 'EMPLEO'],
#       dtype='object')

# %%
# Recordemos que la variable CH06 encapsula lo referido a las edades de los encuestados. Por lo que la utilizamos para crear "edad2"

df['edad2'] = df['CH06'] ** 2

# %%
df.columns
# Out:
# Index(['CH04', 'CH06', 'CH07', 'CH08', 'NIVEL_ED', 'ESTADO', 'CAT_INAC',
#        'IPCF', 'CH14', 'CH15_COD', 'CH16_COD', 'PP03C', 'PP04B_COD', 'PP06H',
#        'PP07A', 'AÑO', 'CAT_OCUP', 'PP07H', 'informal', 'EMPLEO', 'edad2'],
#       dtype='object')

# %%
# Realicemos los graficos pedidoos

# %%
sns.set(style="white")

fig, axs = plt.subplots(1, 2, figsize=(12, 5))
fig.subplots_adjust(wspace=0.35)

# Hagamos el histograma para la variable edad

axs[0].hist(df['CH06'].dropna(), bins=30)
axs[0].set_title('Panel A: Distribución de edad')
axs[0].set_xlabel('Edad')
axs[0].set_ylabel('Frecuencia')
axs[0].grid(False)

# Ahora construyamos el segundo panel

formales = df[df['informal'] == 0]['edad2'].dropna()
informales = df[df['informal'] == 1]['edad2'].dropna()

formales.plot.kde(ax=axs[1], label='Formal')
informales.plot.kde(ax=axs[1], label='Informal')

axs[1].set_title('Panel B: Distribución de edad² por formalidad')
axs[1].set_xlabel('Edad²')
axs[1].set_ylabel('Densidad (estimada)')
axs[1].grid(False)
axs[1].legend()

plt.savefig('grafico_edades.png', dpi=300, bbox_inches='tight')

# %%
### Ejercicio 2:

# %%
# Empecemos a creear la variable educ, mediante las variables que ya tenemos de las bases de datos previamente guardadas. 
# Para ello usemos for para determinar que se guarda dentro

# %%
# Vamos a necesitar traer esas variables dado a que no las tenemos dentro de nuestros dataframes,
# para ello sigamos el mismo proceso que utilizamos en el tp1

df1 = pd.read_excel('usu_individual_T325.xlsx')
df2 = pd.read_stata('individual_t305.dta', convert_categoricals=False)

# Homogeneizamos nombres
df2.columns = df2.columns.str.upper()

# Filtramos región de Cuyo (42) en ambas
df1 = df1[df1["REGION"] == 42]
df2 = df2[df2["REGION"] == 42]

# Agregamos variable de año
df1["AÑO"] = 2025
df2["AÑO"] = 2005

# Convertimos las columnas que están en un formato incorrecto en df2 a numérico
formato_incorrecto = [
    'CH14', 'CH15_COD', 'CH16_COD', 'PP04B_COD', 'PP04D_COD', 'PP11B_COD',
    'PP11D_COD', 'DECOCUR', 'IDECOCUR', 'RDECOCUR', 'GDECOCUR', 'PDECOCUR',
    'ADECOCUR', 'DECINDR', 'IDECINDR', 'RDECINDR', 'GDECINDR', 'PDECINDR',
    'ADECINDR', 'DECIFR', 'IDECIFR', 'RDECIFR', 'GDECIFR', 'PDECIFR',
    'ADECIFR', 'DECCFR', 'IDECCFR', 'RDECCFR', 'GDECCFR', 'PDECCFR', 'ADECCFR'
]

for col in formato_incorrecto:
    if col in df2.columns:
        df2[col] = pd.to_numeric(df2[col], errors='coerce')

# Merge vertical
df_original = pd.concat([df1, df2], ignore_index=True)
df_original2 = df_original.copy()
df_original3 = df_original.copy()

# Nos quedamos con las variables de interés, incluyendo CH12, CH13 y CH14
columnas_interes = ['AÑO','CH12', 'CH13', 'CH14']

df_original = df_original[columnas_interes]

# %%
df_original.head()
# Out:
#     AÑO  CH12  CH13  CH14
# 0  2025   2.0   2.0   2.0
# 1  2025   0.0   0.0   NaN
# 2  2025   2.0   2.0   2.0
# 3  2025   4.0   1.0   NaN
# 4  2025   9.0   2.0  98.0

# %%
# Creemos ahora la variable educ dentro del dataframe

df_original['educ'] = np.nan

# %%
df_original.columns
# Out:
# Index(['AÑO', 'CH12', 'CH13', 'CH14', 'educ'], dtype='object')

# %%
# 1) Jardín / preescolar
# Lo más razonable es asignar 0 años de educación formal completa
df_original.loc[df_original['CH12'] == 1, 'educ'] = 0

# %%
# 2) Primario incompleto
df_original.loc[(df_original['CH12'] == 2) & (df_original['CH13'] == 2), 'educ'] = df_original['CH14']

# 3) Primario completo
df_original.loc[(df_original['CH12'] == 2) & (df_original['CH13'] == 1), 'educ'] = 6

# %%
# 4) EGB
# EGB se puede interpretar como hasta 9 años
df_original.loc[(df_original['CH12'] == 3) & (df_original['CH13'] == 2) & (df_original['CH14'].between(0, 9)), 'educ'] = df_original['CH14']
df_original.loc[(df_original['CH12'] == 3) & (df_original['CH13'] == 1), 'educ'] = 9

# %%
# 5) Secundario incompleto
df_original.loc[(df_original['CH12'] == 3) & (df_original['CH13'] == 2), 'educ'] = 6 + df_original['CH14']

# 6) Secundario completo
df_original.loc[(df_original['CH12'] == 3) & (df_original['CH13'] == 1), 'educ'] = 12

# %%
# 7) Polimodal
# Polimodal completo equivale a secundario completo
# como dura 3 años después de EGB, incompleto = 9 + año aprobado
df_original.loc[(df_original['CH12'] == 5) & (df_original['CH13'] == 2) & (df_original['CH14'].between(0, 3)), 'educ'] = 9 + df_original['CH14']
df_original.loc[(df_original['CH12'] == 5) & (df_original['CH13'] == 1), 'educ'] = 12

# %%
# 8) Terciario
# incompleto: 12 + año aprobado
df_original.loc[(df_original['CH12'] == 6) & (df_original['CH13'] == 2) & (df_original['CH14'].between(0, 9)), 'educ'] = 12 + df_original['CH14']

# completo: asumimos 3 años
df_original.loc[(df_original['CH12'] == 6) & (df_original['CH13'] == 1), 'educ'] = 15

# %%
# 8) Universitario
df_original.loc[(df_original['CH12'] == 7) & (df_original['CH13'] == 2) & (df_original['CH14'].between(0, 9)), 'educ'] = 12 + df_original['CH14']

# completo: asumimos 5 años
df_original.loc[(df_original['CH12'] == 7) & (df_original['CH13'] == 1), 'educ'] = 17

# %%
# 9) Posgrado
df_original.loc[(df_original['CH12'] == 8) & (df_original['CH13'] == 2) & (df_original['CH14'].between(0, 9)), 'educ'] = 17 + df_original['CH14']
df_original.loc[(df_original['CH12'] == 8) & (df_original['CH13'] == 1), 'educ'] = 19

# %%
# 10) Educación especial -> mejor dejar missing
df_original.loc[df_original['CH12'] == 9, 'educ'] = np.nan

# %%
df_original
# Out:
#        AÑO  CH12  CH13  CH14  educ
# 0     2025   2.0   2.0   2.0   2.0
# 1     2025   0.0   0.0   NaN   NaN
# 2     2025   2.0   2.0   2.0   2.0
# 3     2025   4.0   1.0   NaN   NaN
# 4     2025   9.0   2.0  98.0   NaN
# ...    ...   ...   ...   ...   ...
# 9259  2005   4.0   2.0   3.0   NaN
# 9260  2005   3.0   2.0   1.0   7.0
# 9261  2005   1.0   2.0   0.0   0.0
# 9262  2005   0.0   0.0   NaN   NaN
# 9263  2005   2.0   1.0   NaN   6.0
#
# [9264 rows x 5 columns]

# %%
# Hagamos entonces la estadistica descriptiva que nos estan pidiendo para esta variable:

# %%
df_original['educ'].describe()
# Out:
# count    5655.000000
# mean        9.571883
# std         6.991942
# min         0.000000
# 25%         6.000000
# 50%         9.000000
# 75%        14.000000
# max        99.000000
# Name: educ, dtype: float64

# %%
### Ejercicio 3:

# %%
# Veamos a la variable que necesitamos actualizar

df_original2['ITF']
# Out:
# 0       1252000.0
# 1       1252000.0
# 2       1252000.0
# 3       1252000.0
# 4       1252000.0
#           ...
# 9259        750.0
# 9260        750.0
# 9261        750.0
# 9262        750.0
# 9263        750.0
# Name: ITF, Length: 9264, dtype: float64

# %%
# Creemos una variable con el nomnbre que nos pide

df_original2['ingreso_total_familiar'] = df_original2['ITF']

# %%
# Necesitamos un factor de inflación para poder actualizar los datos. 
# Para ello usamos la calculadora de inflación para ver cuanto valdría un peso en enero de 2005 en enero de 2025.
# Usando la página dada de "https://calculadoradeinflacion.com/argentina.html?md=enero&ad=2005&mh=enero&ah=2025&q=1&s=cpi"
# podemos ver que 1$ en 2005 equivaldria hoy $949.04, por lo que este sera nuestro factor.

factor = 949.04

df_original2.loc[df_original2['ANO4'] == 2005, 'ingreso_total_familiar'] *= factor

df_original2['ingreso_total_familiar']
# Out:
# 0       1252000.0
# 1       1252000.0
# 2       1252000.0
# 3       1252000.0
# 4       1252000.0
#           ...
# 9259     711780.0
# 9260     711780.0
# 9261     711780.0
# 9262     711780.0
# 9263     711780.0
# Name: ingreso_total_familiar, Length: 9264, dtype: float64

# %%
df_original2
# Out:
#                              CODUSU    ANO4  TRIMESTRE  NRO_HOGAR  COMPONENTE  \
# 0     TQRMNOTYPHKOKQCDEHNHB00867020  2025.0        3.0        1.0         8.0
# 1     TQRMNOTYPHKOKQCDEHNHB00867020  2025.0        3.0        1.0         9.0
# 2     TQRMNOTYPHKOKQCDEHNHB00867020  2025.0        3.0        1.0         1.0
# 3     TQRMNOTYPHKOKQCDEHNHB00867020  2025.0        3.0        1.0         2.0
# 4     TQRMNOTYPHKOKQCDEHNHB00867020  2025.0        3.0        1.0         3.0
# ...                             ...     ...        ...        ...         ...
# 9259                       287829    2005.0        3.0        1.0         2.0
# 9260                       287829    2005.0        3.0        1.0         3.0
# 9261                       287829    2005.0        3.0        1.0         4.0
# 9262                       287829    2005.0        3.0        1.0         5.0
# 9263                       287829    2005.0        3.0        1.0         6.0
#
#       H15  REGION MAS_500  AGLOMERADO  PONDERA  ...   AÑO   V2_M V5_M  V11_M  \
# 0     0.0    42.0       S        27.0    528.0  ...  2025    NaN  NaN    NaN
# 1     0.0    42.0       S        27.0    528.0  ...  2025    NaN  NaN    NaN
# 2     1.0    42.0       S        27.0    528.0  ...  2025    NaN  NaN    NaN
# 3     1.0    42.0       S        27.0    528.0  ...  2025    NaN  NaN    NaN
# 4     1.0    42.0       S        27.0    528.0  ...  2025    NaN  NaN    NaN
# ...   ...     ...     ...         ...      ...  ...   ...    ...  ...    ...
# 9259  1.0    42.0       N        27.0    227.0  ...  2005    0.0  0.0    0.0
# 9260  0.0    42.0       N        27.0    227.0  ...  2005    0.0  0.0    0.0
# 9261  0.0    42.0       N        27.0    227.0  ...  2005    0.0  0.0    0.0
# 9262  0.0    42.0       N        27.0    227.0  ...  2005    0.0  0.0    0.0
# 9263  1.0    42.0       N        27.0    227.0  ...  2005  200.0  0.0    0.0
#
#       V21_M  PJ1_1  PJ2_1  PJ3_1  IDIMPP  ingreso_total_familiar
# 0       NaN    NaN    NaN    NaN     NaN               1252000.0
# 1       NaN    NaN    NaN    NaN     NaN               1252000.0
# 2       NaN    NaN    NaN    NaN     NaN               1252000.0
# 3       NaN    NaN    NaN    NaN     NaN               1252000.0
# 4       NaN    NaN    NaN    NaN     NaN               1252000.0
# ...     ...    ...    ...    ...     ...                     ...
# 9259    0.0    0.0    0.0    0.0   00000                711780.0
# 9260    0.0    0.0    0.0    0.0   00000                711780.0
# 9261    0.0    0.0    0.0    0.0   00000                711780.0
# 9262    0.0    0.0    0.0    0.0   00000                711780.0
# 9263    0.0    0.0    0.0    0.0   00000                711780.0
#
# [9264 rows x 245 columns]

# %%
## Construyamos los gráficos pedidos.
from matplotlib.ticker import ScalarFormatter

sns.set(style="white")

fig, axs = plt.subplots(1, 2, figsize=(13, 5))
fig.subplots_adjust(wspace=0.45)

# Para que el eje x sea más legible, expresamos el ingreso en millones de pesos de 2025
df_original2['ingreso_total_familiar_mill'] = df_original2['ingreso_total_familiar'] / 1_000_000

# Hagamos el histograma ITF

axs[0].hist(df_original2['ingreso_total_familiar_mill'].dropna(), bins=30)
axs[0].set_title('Panel A: Histograma del ingreso total familiar')
axs[0].set_xlabel('Ingreso total familiar (millones de pesos de 2025)')
axs[0].set_ylabel('Frecuencia')
axs[0].grid(False)

fmt_x0 = ScalarFormatter(useOffset=False)
fmt_x0.set_scientific(False)
axs[0].xaxis.set_major_formatter(fmt_x0)

# Pasemos a construir el segundo panel:
# Acotamos al p99 para evitar que los outliers aplanen el kernel
p99 = df_original2['ingreso_total_familiar_mill'].quantile(0.99)

# Vamos a necesitar también agregar la columna de informal como para hacer el segundo gráfico. 
df_original2['informal'] = df['informal']

# Separamos el ingreso total familiar según condición de formalidad
formales = df_original2[df_original2['informal'] == 0]['ingreso_total_familiar_mill'].dropna()
informales = df_original2[df_original2['informal'] == 1]['ingreso_total_familiar_mill'].dropna()

# Graficamos las distribuciones kernel para formales e informales,
# restringiendo al percentil 99 para que los valores extremos no aplasten la curva
formales[formales <= p99].plot.kde(ax=axs[1], label='Formal')
informales[informales <= p99].plot.kde(ax=axs[1], label='Informal')

axs[1].set_title('Panel B: Distribución del ingreso por formalidad')
axs[1].set_xlabel('Ingreso total familiar (millones de pesos de 2025)')
axs[1].set_ylabel('Densidad estimada')
axs[1].legend()
axs[1].grid(False)

# Como el kernel puede extenderse artificialmente hacia valores negativos,
# fijamos el límite inferior del eje x en 0
axs[1].set_xlim(left=0)

fmt_x1 = ScalarFormatter(useOffset=False)
fmt_x1.set_scientific(False)
axs[1].xaxis.set_major_formatter(fmt_x1)

fmt_y1 = ScalarFormatter(useOffset=False)
fmt_y1.set_scientific(False)
axs[1].yaxis.set_major_formatter(fmt_y1)

plt.tight_layout()
plt.savefig('grafico_ingresos.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
### Ejercicio 4:

# %%
# Creemos la variable pedida para este ejercicio

df_original2['horastrab'] = np.nan

# Necesitamos unicamente sumar para el jefe del hogar, teniendo cuidado de las missing values que podemos tener

df_original2.loc[df_original2['CH03'] == 1, 'horastrab'] = (
    df_original2['PP3E_TOT'].fillna(0) + df_original2['PP3F_TOT'].fillna(0)
)

# %%
# Realizemos la estadistica descriptiva que nos pide este ejercicio:

# %%
df_original2['horastrab'].describe()
# Out:
# count    2829.000000
# mean       26.867444
# std        24.763273
# min         0.000000
# 25%         0.000000
# 50%        30.000000
# 75%        48.000000
# max       132.000000
# Name: horastrab, dtype: float64

# %%
### Ejercicio 5:

# %%
df_original3['informal'] = df['informal']

# %%
# Ahora si, mediante este dataframe que contiene todo, veamos lo que nos pide analizar en la tabla.

# %%
# Paso 2: cortes por año
base_2005 = df_original3[df_original3['AÑO'] == 2005]
base_2025 = df_original3[df_original3['AÑO'] == 2025]

# Paso 3: calcular cantidades para la tabla
for año, base in [('2005', base_2005), ('2025', base_2025)]:
    total_obs = len(base)
    nas_informal = base['informal'].isna().sum()
    informales = (base['informal'] == 1).sum()
    formales = (base['informal'] == 0).sum()
    
    print(f"\n--- {año} ---")
    print(f"Cantidad de observaciones:               {total_obs}")
    print(f"Observaciones con NAs en informal:       {nas_informal}")
    print(f"Cantidad de informales:                  {informales}")
    print(f"Cantidad de formales:                    {formales}")

# Paso 4: cantidad de variables limpias y homogeneizadas
# Estas son las 15 que limpiaron en el TP1 + las que agregaron después
vars_limpias = ['CH04', 'CH06', 'CH07', 'CH08', 'NIVEL_ED', 'ESTADO', 
                'CAT_INAC', 'IPCF', 'CH14', 'CH15_COD', 'CH16_COD', 
                'PP03C', 'PP04B_COD', 'PP06H', 'PP07A']
print(f"\nCantidad de variables limpias: {len(vars_limpias)}")
# Out:
# --- 2005 ---
# Cantidad de observaciones:               4787
# Observaciones con NAs en informal:       2959
# Cantidad de informales:                  677
# Cantidad de formales:                    1151
#
# --- 2025 ---
# Cantidad de observaciones:               4477
# Observaciones con NAs en informal:       2423
# Cantidad de informales:                  675
# Cantidad de formales:                    1379
#
# Cantidad de variables limpias: 15

# %%
### Parte II:

# %%
df.columns
# Out:
# Index(['CH04', 'CH06', 'CH07', 'CH08', 'NIVEL_ED', 'ESTADO', 'CAT_INAC',
#        'IPCF', 'CH14', 'CH15_COD', 'CH16_COD', 'PP03C', 'PP04B_COD', 'PP06H',
#        'PP07A', 'AÑO', 'CAT_OCUP', 'PP07H', 'informal', 'EMPLEO', 'edad2'],
#       dtype='object')

# %%
df_original.columns
# Out:
# Index(['AÑO', 'CH12', 'CH13', 'CH14', 'educ'], dtype='object')

# %%
df_original2.columns
# Out:
# Index(['CODUSU', 'ANO4', 'TRIMESTRE', 'NRO_HOGAR', 'COMPONENTE', 'H15',
#        'REGION', 'MAS_500', 'AGLOMERADO', 'PONDERA',
#        ...
#        'V5_M', 'V11_M', 'V21_M', 'PJ1_1', 'PJ2_1', 'PJ3_1', 'IDIMPP',
#        'ingreso_total_familiar', 'informal', 'horastrab'],
#       dtype='object', length=247)

# %%
# Para homogeneizar un poco todo, pongamos todo lo que hemos construido hasta ahora dentro de df

# %%
df['CH12'] = df_original['CH12']
df['CH13'] = df_original['CH13']
df['CH14'] = df_original['CH14']
df['educ'] = df_original['educ']
df['ingreso_total_familiar'] = df_original2['ingreso_total_familiar']
df['horastrab'] = df_original2['horastrab']

# %%
df
# Out:
#       CH04  CH06  CH07  CH08  NIVEL_ED  ESTADO  CAT_INAC          IPCF  CH14  \
# 3      1.0  39.0   1.0   4.0       4.0     1.0       0.0  1.391111e+05   NaN
# 6      1.0  35.0   5.0   1.0       6.0     1.0       0.0  2.500000e+06   NaN
# 7      2.0  46.0   3.0   1.0       6.0     1.0       0.0  1.133333e+06   NaN
# 10     1.0  38.0   2.0   1.0       3.0     1.0       0.0  0.000000e+00  99.0
# 11     2.0  42.0   2.0   4.0       3.0     1.0       0.0  0.000000e+00  99.0
# ...    ...   ...   ...   ...       ...     ...       ...           ...   ...
# 9247   1.0  53.0   5.0   1.0       2.0     1.0       0.0  3.800000e+02   NaN
# 9249   1.0  52.0   2.0   4.0       2.0     1.0       0.0  1.533333e+02   NaN
# 9256   2.0  38.0   3.0  12.0       6.0     1.0       0.0  2.500000e+02   NaN
# 9258   1.0  28.0   2.0   4.0       2.0     1.0       0.0  1.250000e+02   NaN
# 9259   2.0  23.0   2.0   4.0       3.0     1.0       0.0  1.250000e+02   3.0
#
#       CH15_COD  ...  CAT_OCUP  PP07H  informal  EMPLEO   edad2  CH12  CH13  \
# 3          NaN  ...       2.0    0.0         0     2.0  1521.0   4.0   1.0
# 6          NaN  ...       3.0    2.0         1     2.0  1225.0   7.0   1.0
# 7          NaN  ...       3.0    1.0         0     1.0  2116.0   7.0   1.0
# 10         NaN  ...       3.0    1.0         0     1.0  1444.0   4.0   2.0
# 11         NaN  ...       3.0    2.0         1     2.0  1764.0   4.0   2.0
# ...        ...  ...       ...    ...       ...     ...     ...   ...   ...
# 9247       NaN  ...       3.0    1.0         0     NaN  2809.0   2.0   1.0
# 9249       NaN  ...       3.0    2.0         1     NaN  2704.0   2.0   1.0
# 9256       NaN  ...       3.0    1.0         0     NaN  1444.0   6.0   1.0
# 9258       NaN  ...       2.0    0.0         0     NaN   784.0   2.0   1.0
# 9259       NaN  ...       3.0    2.0         1     NaN   529.0   4.0   2.0
#
#       educ  ingreso_total_familiar  horastrab
# 3      NaN               1252000.0        NaN
# 6     17.0               2500000.0       48.0
# 7     17.0               3400000.0       45.0
# 10     NaN                     0.0       44.0
# 11     NaN                     0.0        NaN
# ...    ...                     ...        ...
# 9247   6.0               1081905.6        NaN
# 9249   6.0                436558.4      114.0
# 9256  15.0                474520.0       49.0
# 9258   6.0                711780.0        4.0
# 9259   NaN                711780.0        NaN
#
# [3882 rows x 26 columns]

# %%
# Como nos falta únicamente las variables de 2005=IX_TOT y 2025=IX_Tot, tenemos que construirlas para hacer el resto de ejercicios.

# %%
# Paso 1: construir ix_tot en df_original2 (base completa)
df_original2['ix_tot'] = df_original2.groupby(
    ['CODUSU', 'NRO_HOGAR']
)['COMPONENTE'].transform('count')

# Verificación rápida
print(df_original2['ix_tot'].describe())
print(df_original2['ix_tot'].value_counts().head(10))
# Out:
# count    9264.000000
# mean        4.307211
# std         2.032333
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         5.000000
# max        12.000000
# Name: ix_tot, dtype: float64
# ix_tot
# 4     2136
# 3     1599
# 5     1595
# 2     1282
# 6      972
# 1      491
# 7      490
# 8      304
# 9      216
# 10     100
# Name: count, dtype: int64

# %%
# Paso 2: pasar ix_tot a df (que es la base de ocupados)

df['ix_tot'] = df_original2.loc[df.index, 'ix_tot'].values

# Verificación
print(df['ix_tot'].describe())
# Out:
# count    3882.000000
# mean        4.014426
# std         1.886853
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         5.000000
# max        12.000000
# Name: ix_tot, dtype: float64

# %%
df
# Out:
#       CH04  CH06  CH07  CH08  NIVEL_ED  ESTADO  CAT_INAC          IPCF  CH14  \
# 3      1.0  39.0   1.0   4.0       4.0     1.0       0.0  1.391111e+05   NaN
# 6      1.0  35.0   5.0   1.0       6.0     1.0       0.0  2.500000e+06   NaN
# 7      2.0  46.0   3.0   1.0       6.0     1.0       0.0  1.133333e+06   NaN
# 10     1.0  38.0   2.0   1.0       3.0     1.0       0.0  0.000000e+00  99.0
# 11     2.0  42.0   2.0   4.0       3.0     1.0       0.0  0.000000e+00  99.0
# ...    ...   ...   ...   ...       ...     ...       ...           ...   ...
# 9247   1.0  53.0   5.0   1.0       2.0     1.0       0.0  3.800000e+02   NaN
# 9249   1.0  52.0   2.0   4.0       2.0     1.0       0.0  1.533333e+02   NaN
# 9256   2.0  38.0   3.0  12.0       6.0     1.0       0.0  2.500000e+02   NaN
# 9258   1.0  28.0   2.0   4.0       2.0     1.0       0.0  1.250000e+02   NaN
# 9259   2.0  23.0   2.0   4.0       3.0     1.0       0.0  1.250000e+02   3.0
#
#       CH15_COD  ...  PP07H  informal  EMPLEO   edad2  CH12  CH13  educ  \
# 3          NaN  ...    0.0         0     2.0  1521.0   4.0   1.0   NaN
# 6          NaN  ...    2.0         1     2.0  1225.0   7.0   1.0  17.0
# 7          NaN  ...    1.0         0     1.0  2116.0   7.0   1.0  17.0
# 10         NaN  ...    1.0         0     1.0  1444.0   4.0   2.0   NaN
# 11         NaN  ...    2.0         1     2.0  1764.0   4.0   2.0   NaN
# ...        ...  ...    ...       ...     ...     ...   ...   ...   ...
# 9247       NaN  ...    1.0         0     NaN  2809.0   2.0   1.0   6.0
# 9249       NaN  ...    2.0         1     NaN  2704.0   2.0   1.0   6.0
# 9256       NaN  ...    1.0         0     NaN  1444.0   6.0   1.0  15.0
# 9258       NaN  ...    0.0         0     NaN   784.0   2.0   1.0   6.0
# 9259       NaN  ...    2.0         1     NaN   529.0   4.0   2.0   NaN
#
#       ingreso_total_familiar  horastrab  ix_tot
# 3                  1252000.0        NaN       9
# 6                  2500000.0       48.0       1
# 7                  3400000.0       45.0       3
# 10                       0.0       44.0      10
# 11                       0.0        NaN      10
# ...                      ...        ...     ...
# 9247               1081905.6        NaN       3
# 9249                436558.4      114.0       3
# 9256                474520.0       49.0       2
# 9258                711780.0        4.0       6
# 9259                711780.0        NaN       6
#
# [3882 rows x 27 columns]

# %%
### Clusters:

# %%
### 5a) Cluster de k-medias

# %%
# Veamos entonces primero con las variables relevantes que nos piden para este ejercicio

vars_cluster = ['CH06', 'edad2', 'educ', 'ingreso_total_familiar', 'ix_tot', 'horastrab']

df_cluster = df[vars_cluster].dropna()

# %%
# Ahora para que sea correcto el procedimiento, tenemos que estandarizar a las varaibles

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_cluster)

# %%
# Ahora si, probemos con disitintos k:

from sklearn.cluster import KMeans

resultados = {}

for k in [2, 3, 4]:
    kmeans = KMeans(n_clusters=k, random_state=0)
    clusters = kmeans.fit_predict(X_scaled)
    
    df_cluster[f'cluster_{k}'] = clusters
    resultados[k] = kmeans.inertia_

# %%
resultados
# Out:
# {2: 4996.488665087133, 3: 4394.229650173524, 4: 3787.038052758802}

# %%
### 5b)

# %%
# Construyamos la inspección visual de Elbow para saber que k nos sirve para el rango dado:
sns.set_style("white")
inertia = []

for k in range(1, 11):  # hasta 10 inclusive
    kmeans = KMeans(n_clusters=k, n_init=20, random_state=0)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

plt.plot(range(1, 11), inertia)
plt.xlabel('Número de clusters')
plt.ylabel('Inercia')
plt.title('Método del codo')
plt.savefig('metodocodo.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Ver composición de informales por cluster
df_cluster['cluster'] = kmeans.labels_
df_cluster['informal'] = df.loc[df_cluster.index, 'informal'].values
print(df_cluster.groupby('cluster')['informal'].mean())
# Out:
# cluster
# 0    0.192308
# 1    0.285714
# 2    0.088235
# 3    0.307692
# 4    0.344086
# 5    0.085938
# 6    0.250000
# 7    0.203704
# 8    0.504425
# 9    0.246305
# Name: informal, dtype: float64

# %%
### Ejercicio 6)

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
sns.set_style("white")

Z = linkage(X_scaled, method='ward')

plt.figure(figsize=(12, 6))
dendrogram(
    Z,
    truncate_mode='lastp',  # muestra solo los últimos p nodos
    p=20,                    # cantidad de nodos a mostrar
    leaf_rotation=90,
    leaf_font_size=10,
    show_contracted=True     # muestra punto en nodos contraídos
)
plt.title('Dendrograma')
plt.xlabel('Observaciones')
plt.ylabel('Distancia')
plt.tight_layout()
plt.savefig('dendrograma.png', dpi=300, bbox_inches='tight')
plt.show()
