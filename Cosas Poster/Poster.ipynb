# %%
#Importamos paquetes
import pandas as pd
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
os.chdir(r"C:\Users\Gaelj\OneDrive\Documentos\Universidad San Andres\4° Año\Big Data\Cosas Poster")

# %%
### Encuesta México Victimización

# %%
# Abramos primero las bases que tenemos

# %%
df_mexvict_hogar = pd.read_csv(r"C:\Users\Gaelj\OneDrive\Documentos\Universidad San Andres\4° Año\Big Data\Cosas Poster\Encuesta México Victimización\THogar.csv")

# %%
df_mexvict_hogar # Características de los hogares que componen la vivienda seleccionada.
# Out:
#        Unnamed: 0      ID_VIV         ID_HOG      UPM  VIV_SEL  HOGAR RESUL_H  \
# 0               1   100107.01  0100107.01.01   100107        1      1       B
# 1               2   100107.02  0100107.02.01   100107        2      1       A
# 2               3   100107.03  0100107.03.01   100107        3      1       B
# 3               4   100107.04  0100107.04.01   100107        4      1       A
# 4               5   100107.05  0100107.05.01   100107        5      1       B
# ...           ...         ...            ...      ...      ...    ...     ...
# 91325       91326  3261231.16  3261231.16.01  3261231       16      1       B
# 91326       91327  3261231.17  3261231.17.01  3261231       17      1       B
# 91327       91328  3261231.18  3261231.18.01  3261231       18      1       B
# 91328       91329  3261231.19  3261231.19.01  3261231       19      1       B
# 91329       91330  3261231.20  3261231.20.01  3261231       20      1       A
#
#        N_INF  R_SEL  CVE_ENT         NOM_ENT  CVE_MUN         NOM_MUN  \
# 0        1.0    1.0        1  AGUASCALIENTES        1  AGUASCALIENTES
# 1        1.0    2.0        1  AGUASCALIENTES        1  AGUASCALIENTES
# 2        1.0    4.0        1  AGUASCALIENTES        1  AGUASCALIENTES
# 3        2.0    3.0        1  AGUASCALIENTES        1  AGUASCALIENTES
# 4        1.0    1.0        1  AGUASCALIENTES        1  AGUASCALIENTES
# ...      ...    ...      ...             ...      ...             ...
# 91325    1.0    1.0       32       ZACATECAS       51    VILLA DE COS
# 91326    1.0    1.0       32       ZACATECAS       51    VILLA DE COS
# 91327    1.0    1.0       32       ZACATECAS       51    VILLA DE COS
# 91328    2.0    2.0       32       ZACATECAS       51    VILLA DE COS
# 91329    1.0    1.0       32       ZACATECAS       51    VILLA DE COS
#
#        TOT_PER  FAC_HOG  FAC_HOG_AM DOMINIO  EST_DIS  UPM_DIS
# 0          1.0    241.0       241.0       U        1       47
# 1          4.0    241.0       241.0       U        1       47
# 2          4.0    241.0       241.0       U        1       47
# 3          4.0    241.0       241.0       U        1       47
# 4          4.0    241.0       241.0       U        1       47
# ...        ...      ...         ...     ...      ...      ...
# 91325      1.0    282.0         NaN       R      746    13744
# 91326      4.0    282.0         NaN       R      746    13744
# 91327      1.0    282.0         NaN       R      746    13744
# 91328      4.0    282.0         NaN       R      746    13744
# 91329      2.0    282.0         NaN       R      746    13744
#
# [91330 rows x 19 columns]

# %%
df_Mod_Vic = pd.read_csv(r"C:\Users\Gaelj\OneDrive\Documentos\Universidad San Andres\4° Año\Big Data\Cosas Poster\Encuesta México Victimización\TMod_Vic.csv")

# %%
df_Mod_Vic #Características correspondientes a los delitos captados por el módulo sobre victimización.
# Out:
#        Unnamed: 0      ID_VIV         ID_HOG            ID_PER  \
# 0               1   100271.01  0100271.01.01  0100271.01.01.02
# 1               2   100149.02  0100149.02.01  0100149.02.01.04
# 2               3   102068.05  0102068.05.01  0102068.05.01.01
# 3               4   100255.05  0100255.05.01  0100255.05.01.02
# 4               5   100461.05  0100461.05.01  0100461.05.01.01
# ...           ...         ...            ...               ...
# 40275       40276  1900792.01  1900792.01.01  1900792.01.01.01
# 40276       40277  3017025.03  3017025.03.01  3017025.03.01.01
# 40277       40278  2203439.13  2203439.13.01  2203439.13.01.01
# 40278       40279  2804521.03  2804521.03.01  2804521.03.01.02
# 40279       40280  2203439.13  2203439.13.01  2203439.13.01.01
#
#                       ID_DEL      UPM  VIV_SEL  HOGAR  ND_TIPO  TD_TIPO  ...  \
# 0      0100271.01.01.02.05.1   100271        1      1        1        2  ...
# 1      0100149.02.01.04.02.1   100149        2      1        1        1  ...
# 2      0102068.05.01.01.05.1   102068        5      1        1        1  ...
# 3      0100255.05.01.02.02.1   100255        5      1        1        1  ...
# 4      0100461.05.01.01.04.1   100461        5      1        1        2  ...
# ...                      ...      ...      ...    ...      ...      ...  ...
# 40275  1900792.01.01.01.07.1  1900792        1      1        1        1  ...
# 40276  3017025.03.01.01.07.1  3017025        3      1        1        1  ...
# 40277  2203439.13.01.01.07.3  2203439       13      1        3        3  ...
# 40278  2804521.03.01.02.15.1  2804521        3      1        1        1  ...
# 40279  2203439.13.01.01.07.1  2203439       13      1        1        3  ...
#
#        BP6_1  BP6_2 BP6_3  BP7_1  FAC_DEL  FAC_DEL_AM  DOMINIO  ESTRATO  \
# 0        NaN    NaN   NaN    NaN      606       606.0        U        1
# 1        NaN    NaN   NaN    NaN      242       242.0        U        2
# 2        NaN    NaN   NaN    NaN      279       279.0        U        2
# 3        NaN    NaN   NaN    NaN      198       198.0        U        3
# 4        NaN    NaN   NaN    NaN      255       255.0        U        4
# ...      ...    ...   ...    ...      ...         ...      ...      ...
# 40275    NaN    NaN   NaN    NaN      770         NaN        U        4
# 40276    NaN    NaN   NaN    NaN     1331         NaN        U        2
# 40277    NaN    NaN   NaN    NaN     1436         NaN        C        4
# 40278    NaN    NaN   NaN    NaN      505         NaN        U        3
# 40279    NaN    NaN   NaN    NaN     1436         NaN        C        4
#
#        EST_DIS  UPM_DIS
# 0            1       87
# 1            1       46
# 2            1        6
# 3            2      174
# 4            3      229
# ...        ...      ...
# 40275      410     8392
# 40276      701    12966
# 40277      499     9692
# 40278      627    12164
# 40279      499     9692
#
# [40280 rows x 138 columns]

# %%
df_TPer_Vic1 = pd.read_csv(r"C:\Users\Gaelj\OneDrive\Documentos\Universidad San Andres\4° Año\Big Data\Cosas Poster\Encuesta México Victimización\TPer_Vic1.csv")

# %%
df_TPer_Vic1 #Variables correspondientes a la percepción de seguridad pública y el desempeño institucional.
# Out:
#        Unnamed: 0      ID_VIV         ID_HOG            ID_PER      UPM  \
# 0               1   100107.01  0100107.01.01  0100107.01.01.01   100107
# 1               2   100107.02  0100107.02.01  0100107.02.01.02   100107
# 2               3   100107.03  0100107.03.01  0100107.03.01.04   100107
# 3               4   100107.04  0100107.04.01  0100107.04.01.03   100107
# 4               5   100107.05  0100107.05.01  0100107.05.01.01   100107
# ...           ...         ...            ...               ...      ...
# 91177       91178  3261231.16  3261231.16.01  3261231.16.01.01  3261231
# 91178       91179  3261231.17  3261231.17.01  3261231.17.01.01  3261231
# 91179       91180  3261231.18  3261231.18.01  3261231.18.01.01  3261231
# 91180       91181  3261231.19  3261231.19.01  3261231.19.01.02  3261231
# 91181       91182  3261231.20  3261231.20.01  3261231.20.01.01  3261231
#
#        VIV_SEL  HOGAR RESUL_H  R_SEL  SEXO  ...  AP5_8_11_5  AP5_9  FAC_HOG  \
# 0            1      1       B      1     2  ...         NaN      3      241
# 1            2      1       A      2     2  ...         9.0      2      241
# 2            3      1       B      4     2  ...         NaN      9      241
# 3            4      1       A      3     1  ...         9.0      2      241
# 4            5      1       B      1     2  ...         NaN      2      241
# ...        ...    ...     ...    ...   ...  ...         ...    ...      ...
# 91177       16      1       B      1     1  ...         NaN      3      282
# 91178       17      1       B      1     2  ...         NaN      2      282
# 91179       18      1       B      1     2  ...         NaN      9      282
# 91180       19      1       B      2     2  ...         NaN      2      282
# 91181       20      1       A      1     1  ...         NaN      4      282
#
#       FAC_ELE  FAC_HOG_AM FAC_ELE_AM  DOMINIO  ESTRATO  EST_DIS  UPM_DIS
# 0         241       241.0      241.0        U        2        1       47
# 1         482       241.0      482.0        U        2        1       47
# 2         963       241.0      963.0        U        2        1       47
# 3         723       241.0      723.0        U        2        1       47
# 4         482       241.0      482.0        U        2        1       47
# ...       ...         ...        ...      ...      ...      ...      ...
# 91177     282         NaN        NaN        R        2      746    13744
# 91178     282         NaN        NaN        R        2      746    13744
# 91179     282         NaN        NaN        R        2      746    13744
# 91180     564         NaN        NaN        R        2      746    13744
# 91181     564         NaN        NaN        R        2      746    13744
#
# [91182 rows x 241 columns]

# %%
df_TPer_Vic2 = pd.read_csv(r"C:\Users\Gaelj\OneDrive\Documentos\Universidad San Andres\4° Año\Big Data\Cosas Poster\Encuesta México Victimización\TPer_Vic2.csv")

# %%
df_TPer_Vic2 #Características correspondientes a la victimización en el hogar y personal.
# Out:
#        Unnamed: 0      ID_VIV         ID_HOG            ID_PER      UPM  \
# 0               1   100107.01  0100107.01.01  0100107.01.01.01   100107
# 1               2   100107.02  0100107.02.01  0100107.02.01.02   100107
# 2               3   100107.03  0100107.03.01  0100107.03.01.04   100107
# 3               4   100107.04  0100107.04.01  0100107.04.01.03   100107
# 4               5   100107.05  0100107.05.01  0100107.05.01.01   100107
# ...           ...         ...            ...               ...      ...
# 91177       91178  3261231.16  3261231.16.01  3261231.16.01.01  3261231
# 91178       91179  3261231.17  3261231.17.01  3261231.17.01.01  3261231
# 91179       91180  3261231.18  3261231.18.01  3261231.18.01.01  3261231
# 91180       91181  3261231.19  3261231.19.01  3261231.19.01.02  3261231
# 91181       91182  3261231.20  3261231.20.01  3261231.20.01.01  3261231
#
#        VIV_SEL  HOGAR RESUL_H  R_SEL  SEXO  ...  AP7_3_15  AP7_4_15  FAC_HOG  \
# 0            1      1       B      1     2  ...         2       NaN      241
# 1            2      1       A      2     2  ...         2       NaN      241
# 2            3      1       B      4     2  ...         2       NaN      241
# 3            4      1       A      3     1  ...         2       NaN      241
# 4            5      1       B      1     2  ...         2       NaN      241
# ...        ...    ...     ...    ...   ...  ...       ...       ...      ...
# 91177       16      1       B      1     1  ...         2       NaN      282
# 91178       17      1       B      1     2  ...         2       NaN      282
# 91179       18      1       B      1     2  ...         2       NaN      282
# 91180       19      1       B      2     2  ...         2       NaN      282
# 91181       20      1       A      1     1  ...         2       NaN      282
#
#       FAC_ELE  FAC_HOG_AM FAC_ELE_AM  DOMINIO  ESTRATO  EST_DIS  UPM_DIS
# 0         241       241.0      241.0        U        2        1       47
# 1         482       241.0      482.0        U        2        1       47
# 2         963       241.0      963.0        U        2        1       47
# 3         723       241.0      723.0        U        2        1       47
# 4         482       241.0      482.0        U        2        1       47
# ...       ...         ...        ...      ...      ...      ...      ...
# 91177     282         NaN        NaN        R        2      746    13744
# 91178     282         NaN        NaN        R        2      746    13744
# 91179     282         NaN        NaN        R        2      746    13744
# 91180     564         NaN        NaN        R        2      746    13744
# 91181     564         NaN        NaN        R        2      746    13744
#
# [91182 rows x 150 columns]

# %%
df_TSDem = pd.read_csv(r"C:\Users\Gaelj\OneDrive\Documentos\Universidad San Andres\4° Año\Big Data\Cosas Poster\Encuesta México Victimización\TSDem.csv")

# %%
df_TSDem #Características sociodemográficas correspondientes a los integrantes del hogar
# Out:
#         Unnamed: 0      ID_VIV         ID_HOG            ID_PER      UPM  \
# 0                1   100107.01  0100107.01.01  0100107.01.01.01   100107
# 1                2   100107.02  0100107.02.01  0100107.02.01.01   100107
# 2                3   100107.02  0100107.02.01  0100107.02.01.02   100107
# 3                4   100107.02  0100107.02.01  0100107.02.01.03   100107
# 4                5   100107.02  0100107.02.01  0100107.02.01.04   100107
# ...            ...         ...            ...               ...      ...
# 300649      300650  3261231.19  3261231.19.01  3261231.19.01.02  3261231
# 300650      300651  3261231.19  3261231.19.01  3261231.19.01.03  3261231
# 300651      300652  3261231.19  3261231.19.01  3261231.19.01.04  3261231
# 300652      300653  3261231.20  3261231.20.01  3261231.20.01.01  3261231
# 300653      300654  3261231.20  3261231.20.01  3261231.20.01.02  3261231
#
#         VIV_SEL  HOGAR RESUL_H  CVE_ENT         NOM_ENT  ...  NIV  GRA  AP3_8  \
# 0             1      1       B        1  AGUASCALIENTES  ...  3.0  2.0    1.0
# 1             2      1       A        1  AGUASCALIENTES  ...  6.0  3.0    1.0
# 2             2      1       A        1  AGUASCALIENTES  ...  6.0  3.0    1.0
# 3             2      1       A        1  AGUASCALIENTES  ...  2.0  4.0    NaN
# 4             2      1       A        1  AGUASCALIENTES  ...  1.0  3.0    NaN
# ...         ...    ...     ...      ...             ...  ...  ...  ...    ...
# 300649       19      1       B       32       ZACATECAS  ...  3.0  3.0    1.0
# 300650       19      1       B       32       ZACATECAS  ...  3.0  3.0    NaN
# 300651       19      1       B       32       ZACATECAS  ...  2.0  1.0    NaN
# 300652       20      1       A       32       ZACATECAS  ...  3.0  3.0    1.0
# 300653       20      1       A       32       ZACATECAS  ...  2.0  5.0    1.0
#
#         AP3_9  AP3_10  FAC_HOG  FAC_HOG_AM  DOMINIO  EST_DIS  UPM_DIS
# 0         NaN     2.0      241       241.0        U        1       47
# 1         NaN     2.0      241       241.0        U        1       47
# 2         NaN     2.0      241       241.0        U        1       47
# 3         NaN     NaN      241       241.0        U        1       47
# 4         NaN     NaN      241       241.0        U        1       47
# ...       ...     ...      ...         ...      ...      ...      ...
# 300649    NaN     1.0      282         NaN        R      746    13744
# 300650    NaN     NaN      282         NaN        R      746    13744
# 300651    NaN     NaN      282         NaN        R      746    13744
# 300652    NaN     1.0      282         NaN        R      746    13744
# 300653    NaN     1.0      282         NaN        R      746    13744
#
# [300654 rows x 27 columns]

# %%
df_TVivienda = pd.read_csv(r"C:\Users\Gaelj\OneDrive\Documentos\Universidad San Andres\4° Año\Big Data\Cosas Poster\Encuesta México Victimización\TVivienda.csv")

# %%
df_TVivienda # Características de las viviendas seleccionadas, sus integrantes y los hogares que las conforman.
# Out:
#        Unnamed: 0      ID_VIV      UPM  VIV_SEL  AREAM  CVE_ENT  \
# 0               1   100107.01   100107        1   14.0        1
# 1               2   100107.02   100107        2   14.0        1
# 2               3   100107.03   100107        3   14.0        1
# 3               4   100107.04   100107        4   14.0        1
# 4               5   100107.05   100107        5   14.0        1
# ...           ...         ...      ...      ...    ...      ...
# 89662       89663  3261231.16  3261231       16    NaN       32
# 89663       89664  3261231.17  3261231       17    NaN       32
# 89664       89665  3261231.18  3261231       18    NaN       32
# 89665       89666  3261231.19  3261231       19    NaN       32
# 89666       89667  3261231.20  3261231       20    NaN       32
#
#               NOM_ENT  CVE_MUN         NOM_MUN  RESULT_V  ...  AP1_2  AP2_1  \
# 0      AGUASCALIENTES        1  AGUASCALIENTES         2  ...      2      1
# 1      AGUASCALIENTES        1  AGUASCALIENTES         1  ...      2      4
# 2      AGUASCALIENTES        1  AGUASCALIENTES         2  ...      2      4
# 3      AGUASCALIENTES        1  AGUASCALIENTES         1  ...      1      4
# 4      AGUASCALIENTES        1  AGUASCALIENTES         2  ...      2      4
# ...               ...      ...             ...       ...  ...    ...    ...
# 89662       ZACATECAS       51    VILLA DE COS         2  ...      2      1
# 89663       ZACATECAS       51    VILLA DE COS         2  ...      2      4
# 89664       ZACATECAS       51    VILLA DE COS         2  ...      2      1
# 89665       ZACATECAS       51    VILLA DE COS         2  ...      2      4
# 89666       ZACATECAS       51    VILLA DE COS         1  ...      2      2
#
#        AP2_2  AP2_3  NAP2_3  FAC_VIV  FAC_VIV_AM  DOMINIO EST_DIS  UPM_DIS
# 0          1    NaN       1      241       241.0        U       1       47
# 1          1    NaN       1      241       241.0        U       1       47
# 2          1    NaN       1      241       241.0        U       1       47
# 3          1    NaN       1      241       241.0        U       1       47
# 4          1    NaN       1      241       241.0        U       1       47
# ...      ...    ...     ...      ...         ...      ...     ...      ...
# 89662      1    NaN       1      282         NaN        R     746    13744
# 89663      1    NaN       1      282         NaN        R     746    13744
# 89664      1    NaN       1      282         NaN        R     746    13744
# 89665      1    NaN       1      282         NaN        R     746    13744
# 89666      1    NaN       1      282         NaN        R     746    13744
#
# [89667 rows x 21 columns]

# %%
#NOM_MUN aparenta ser los municipios que se tienen en la base. Y NOM_ENT seria el nombre de la entidad 

#Por lo que es obvio, si me intereza mirar la persepción sobre la seguridad tendría que ver df_TPer_Vic1

#Antes que nada me gustaría definir que preguntas nos podríamos hacer con esto

# %%
# Preguntas:

# 1) ¿Cómo varía la percepción de inseguridad según sexo y edad?
# 2) ¿La confianza en las instituciones está asociada a la percepción de inseguridad?
# 3) ¿Las víctimas cambian más sus hábitos por miedo al delito?

# %%
### Empecemos entonces buscar una forma de ver la priemra pregunta

# %%
# 1) ¿Cómo varía la percepción de inseguridad según sexo y edad?

# %%
# Para poder ver esto, vamos a neceditar distintas bases, siendo estas df_TSDem y df_TPer_Vic1
# Antes de eso, estaria bueno guardar todo dentro de regiones en vez de tener todos los estados por separado.

# %%
df_TSDem['NOM_ENT']
# Out:
# 0         AGUASCALIENTES
# 1         AGUASCALIENTES
# 2         AGUASCALIENTES
# 3         AGUASCALIENTES
# 4         AGUASCALIENTES
#                ...
# 300649         ZACATECAS
# 300650         ZACATECAS
# 300651         ZACATECAS
# 300652         ZACATECAS
# 300653         ZACATECAS
# Name: NOM_ENT, Length: 300654, dtype: object

# %%
# Estandarizamos a los nombres por las dudas
df_TSDem["NOM_ENT"] = df_TSDem["NOM_ENT"].str.strip().str.upper()
df_TPer_Vic1["NOM_ENT"] = df_TPer_Vic1["NOM_ENT"].str.strip().str.upper()

# Creamos un diccionario para poder identificar mejor cada estado de México
regiones_mexico = {
    "Noroeste": [
        "BAJA CALIFORNIA", "BAJA CALIFORNIA SUR", "CHIHUAHUA",
        "DURANGO", "SINALOA", "SONORA"
    ],
    "Noreste": [
        "COAHUILA DE ZARAGOZA", "NUEVO LEON", "TAMAULIPAS"
    ],
    "Occidente": [
        "COLIMA", "GUANAJUATO", "JALISCO",
        "MICHOACAN DE OCAMPO", "NAYARIT"
    ],
    "Centronorte": [
        "AGUASCALIENTES", "QUERETARO",
        "SAN LUIS POTOSI", "ZACATECAS"
    ],
    "Centrosur": [
        "CIUDAD DE MEXICO", "MEXICO", "MORELOS"
    ],
    "Oriente": [
        "HIDALGO", "PUEBLA", "TLAXCALA",
        "VERACRUZ DE IGNACIO DE LA LLAVE"
    ],
    "Suroeste": [
        "CHIAPAS", "GUERRERO", "OAXACA"
    ],
    "Sureste": [
        "CAMPECHE", "QUINTANA ROO",
        "TABASCO", "YUCATAN"
    ]
}

# %%
# Creamos una función que nos facilite agrupar a los estados
def asignar_region(estado):
    for region, estados in regiones_mexico.items():
        if estado in estados:
            return region
    return "No clasificado"

# Aplicamos la función construida
df_TSDem["region"] = df_TSDem["NOM_ENT"].apply(asignar_region)
df_TPer_Vic1["region"] = df_TPer_Vic1["NOM_ENT"].apply(asignar_region)

# %%
print(df_TSDem["region"].value_counts())
# Out:
# region
# Noroeste       54345
# Occidente      43575
# Oriente        41316
# Sureste        36773
# Centrosur      35038
# Suroeste       32311
# Noreste        30357
# Centronorte    26939
# Name: count, dtype: int64

# %%
df_TSDem[df_TSDem["region"] == "No clasificado"]["NOM_ENT"].drop_duplicates()
# Out:
# Series([], Name: NOM_ENT, dtype: object)

# %%
# Ahora hacemos merge para todo esto
df_analisis = df_TPer_Vic1.merge(
    df_TSDem[["UPM", "VIV_SEL", "HOGAR", "N_REN", "SEXO", "EDAD", "region"]],
    left_on=["UPM", "VIV_SEL", "HOGAR", "R_SEL"],
    right_on=["UPM", "VIV_SEL", "HOGAR", "N_REN"],
    how="inner",
    suffixes=("_vic", "_dem")   
)

# Eliminamos las columnas duplicadas del lado de victimización
# y renombramos las demográficas para que queden limpias
df_analisis = df_analisis.drop(columns=["SEXO_vic", "EDAD_vic", "region_vic"], errors="ignore")
df_analisis = df_analisis.rename(columns={
    "SEXO_dem": "SEXO",
    "EDAD_dem": "EDAD",
    "region_dem": "region"
})

# %%
# Verificación
print(df_analisis[["SEXO", "EDAD", "region"]].head())
print(df_analisis["region"].value_counts())
# Out:
#    SEXO  EDAD       region
# 0     2    56  Centronorte
# 1     2    30  Centronorte
# 2     2    18  Centronorte
# 3     1    22  Centronorte
# 4     2    36  Centronorte
# region
# Noroeste       16889
# Occidente      13458
# Oriente        12103
# Sureste        11231
# Centrosur      11105
# Noreste         9250
# Suroeste        8988
# Centronorte     8158
# Name: count, dtype: int64

# %%
# Una vez con esto construido, podemos ahora si apreciar que variables nos pueden servir para esta pregunta. 
# Por un lado dentro de df_TPer_Vic1, vamos a necesitar a aquellas variables que nos indiquen la persepción general de manera geográfica, cosa que lo hace 
# las varaibles AP4_3_1 (colonia/localidad (1=seguro, 2=inseguro)), AP4_3_2 (municipio (1=seguro, 2=inseguro)), AP4_3_3 (estado (1=seguro, 2=inseguro))

# %%
# Por otro lado, tenemos AP4_4 la sensación de seguridad en lugares específicos, siendo que 
# AP4_4_01 a AP4_4_12 → casa, trabajo, calle, escuela, mercado, centro comercial, banco, cajero, transporte público, auto, carretera, parque.
# AP4_4_A → qué tan seguro se siente caminando solo de noche cerca de su vivienda (escala de 4 puntos: muy seguro → muy inseguro)

# %%
# También AP4_7 como expectativa futura de seguridad, siendo que AP4_7_1, AP4_7_2, AP4_7_3 → si cree que la seguridad mejorará/empeorará en colonia, estado y país

# %%
# Pero, tengamos cuidado con el como se calsificaron los NonValues, porque como nos paso con la EPH esto ocurre para algunas variables

# %%
# En AP4_3, AP4_4: 9 → "No sabe / no responde", 3 → "No aplica" (en AP4_4, por ejemplo alguien que no tiene auto no responde AP4_4_10)
# En AP4_4_A: 5 → "No aplica", 9 → "No sabe / no responde"
# Para las variables geográficas como EDAD: 98 → edad no especificada (este sí es missing)

# %%
# Variables de percepción por ámbito (AP4_3_1, AP4_3_2, AP4_3_3)
cols_ambito = ["AP4_3_1", "AP4_3_2", "AP4_3_3"]
df_analisis[cols_ambito] = df_analisis[cols_ambito].replace([9], np.nan)

# Variables de percepción por lugar (AP4_4_01 a AP4_4_12)
cols_lugares = [f"AP4_4_{str(i).zfill(2)}" for i in range(1, 13)]
df_analisis[cols_lugares] = df_analisis[cols_lugares].replace([3, 9], np.nan)

# AP4_4_A (caminar solo de noche)
df_analisis["AP4_4_A"] = df_analisis["AP4_4_A"].replace([5, 9], np.nan)
df_analisis["EDAD"] = df_analisis["EDAD"].replace([98], np.nan)

# %%
# Contruyamos un heatmap respecto a las missing values que tienen las varaibles, porque para el resto la verdad que no veo el porque.

# %%
# Las variables que nos importan para el análisis
cols_analisis = ["SEXO", "EDAD", "region",
                 "AP4_3_1", "AP4_3_2", "AP4_3_3",
                 "AP4_4_01", "AP4_4_02", "AP4_4_03", "AP4_4_04",
                 "AP4_4_05", "AP4_4_06", "AP4_4_07", "AP4_4_08",
                 "AP4_4_09", "AP4_4_10", "AP4_4_11", "AP4_4_12",
                 "AP4_4_A"]
# Calcular porcentaje de missing por variable
missing_pct = df_analisis[cols_analisis].isnull().mean() * 100

# Convertir a DataFrame para heatmap
missing_df = pd.DataFrame(missing_pct, columns=["% Missing"]).T

# Graficar
plt.figure(figsize=(14, 3))

sns.heatmap(missing_df,
            annot=True,
            fmt=".1f",
            cmap="Greens",
            vmin=0, vmax=100,
            cbar=True)

plt.title("Porcentaje de valores faltantes por variable")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()

plt.show()

# %%
# Para la varaible AP4_4_04 que corresponde ¿En términos de delincuencia, considera que vivir en la escuela es... termina teniendo un alto porcentaje de missing values.

# %%
# Veamos mediante un histograma la proporción de sexo masculino y femenino para la muestra

# %%
df_analisis['SEXO']
# Out:
# 0        2
# 1        2
# 2        2
# 3        1
# 4        2
#         ..
# 91177    1
# 91178    2
# 91179    2
# 91180    2
# 91181    1
# Name: SEXO, Length: 91182, dtype: int64

# %%
sexo = df_analisis['SEXO'].value_counts(normalize=True) * 100 #normalize es para que efectivamente nos de proporciones en vez de recuentos normales.

# Asumiendo SEXO: 1 = Masculino, 2 = Femenino
valores = [sexo.get(1.0, 0), sexo.get(2.0, 0)]

labels = ['Masculino', 'Femenino']

sns.set(style="whitegrid")

plt.figure(figsize=(6,4))

sns.barplot(x=labels, y=valores)

plt.title("2025")
plt.ylim(0, 60)
plt.ylabel("Proporción (%)")
plt.xlabel("Sexo")

plt.tight_layout()
plt.show()

# %%
# Tenemos un porcentaje más alto de encuestados femeninos que respondieron el cuestionario.

# %%
# Para ver una matriz de correlación no nos sirve mucho hacerlo de manera directa porque son categorías binarias practicamente la mayoría de las varaibles que tenemos.
# Así que vamos a tener que hacer una transformación de algun tipo para que sean comparables.

# %%
# Paso 1: Crear dummies para las variables categóricas
dummies = []

# SEXO
df_sexo = df_analisis["SEXO"].astype("string")
dummies.append(pd.get_dummies(df_sexo, prefix="SEXO"))

# REGION
df_region = df_analisis["region"].astype("string")
dummies.append(pd.get_dummies(df_region, prefix="REGION"))

# Definamos las variables de interes:

cols_interest = [
    "AP4_3_1", "AP4_3_2", "AP4_3_3",
    "AP4_4_01", "AP4_4_02", "AP4_4_03", "AP4_4_04",
    "AP4_4_05", "AP4_4_06", "AP4_4_07", "AP4_4_08",
    "AP4_4_09", "AP4_4_10", "AP4_4_11", "AP4_4_12",
    "AP4_4_A"
]

for col in cols_interest:
    df_col = df_analisis[col].astype("string")
    dummies.append(pd.get_dummies(df_col, prefix=col))

# EDAD va directa, es numérica
dummies.append(df_analisis[["EDAD"]])

dummies = pd.concat(dummies, axis=1)

# %%
# Paso 2: Renombrar con etiquetas legibles
rename_dict = {
    # SEXO
    "SEXO_1": "Sexo: Hombre",
    "SEXO_2": "Sexo: Mujer",

    # REGION
    "REGION_Noroeste": "Región: Noroeste",
    "REGION_Noreste": "Región: Noreste",
    "REGION_Occidente": "Región: Occidente",
    "REGION_Centronorte": "Región: Centronorte",
    "REGION_Centrosur": "Región: Centrosur",
    "REGION_Oriente": "Región: Oriente",
    "REGION_Suroeste": "Región: Suroeste",
    "REGION_Sureste": "Región: Sureste",

    # Percepción por ámbito
    "AP4_3_1_1": "Colonia: Seguro",
    "AP4_3_1_2": "Colonia: Inseguro",
    "AP4_3_2_1": "Municipio: Seguro",
    "AP4_3_2_2": "Municipio: Inseguro",
    "AP4_3_3_1": "Estado: Seguro",
    "AP4_3_3_2": "Estado: Inseguro",

    # Percepción por lugar
    "AP4_4_01_1": "Casa: Seguro", "AP4_4_01_2": "Casa: Inseguro",
    "AP4_4_02_1": "Trabajo: Seguro", "AP4_4_02_2": "Trabajo: Inseguro",
    "AP4_4_03_1": "Calle: Seguro", "AP4_4_03_2": "Calle: Inseguro",
    "AP4_4_04_1": "Escuela: Seguro", "AP4_4_04_2": "Escuela: Inseguro",
    "AP4_4_05_1": "Mercado: Seguro", "AP4_4_05_2": "Mercado: Inseguro",
    "AP4_4_06_1": "C.Comercial: Seguro", "AP4_4_06_2": "C.Comercial: Inseguro",
    "AP4_4_07_1": "Banco: Seguro", "AP4_4_07_2": "Banco: Inseguro",
    "AP4_4_08_1": "Cajero: Seguro", "AP4_4_08_2": "Cajero: Inseguro",
    "AP4_4_09_1": "Transporte: Seguro", "AP4_4_09_2": "Transporte: Inseguro",
    "AP4_4_10_1": "Auto: Seguro", "AP4_4_10_2": "Auto: Inseguro",
    "AP4_4_11_1": "Carretera: Seguro", "AP4_4_11_2": "Carretera: Inseguro",
    "AP4_4_12_1": "Parque: Seguro", "AP4_4_12_2": "Parque: Inseguro",

    # Caminar de noche
    "AP4_4_A_1": "Noche: Muy seguro",
    "AP4_4_A_2": "Noche: Seguro",
    "AP4_4_A_3": "Noche: Inseguro",
    "AP4_4_A_4": "Noche: Muy inseguro",

    # EDAD
    "EDAD": "Edad"
}

dummies = dummies.rename(columns=rename_dict)

# %%
# Paso 3: Abreviar
dummies.columns = dummies.columns.str.replace("Región: ", "Reg: ", regex=False)
dummies.columns = dummies.columns.str.replace("Sexo: ", "Sex: ", regex=False)

# Paso 4: Graficar
plt.figure(figsize=(24, 20))
sns.heatmap(dummies.corr(), vmin=-1, vmax=1, cmap="coolwarm")
plt.xticks(rotation=45, ha="right", fontsize=8)
plt.yticks(rotation=0, fontsize=8)
plt.title("Matriz de correlación - Percepción de inseguridad")
plt.tight_layout()
plt.show()

# %%
# Dividimos variables
cols_1 = ["AP4_3_1", "AP4_3_2", "AP4_3_3",
          "AP4_4_01", "AP4_4_02", "AP4_4_03"]

cols_2 = ["AP4_4_04", "AP4_4_05", "AP4_4_06",
          "AP4_4_07", "AP4_4_08", "AP4_4_09",
          "AP4_4_10", "AP4_4_11", "AP4_4_12", "AP4_4_A"]

# Correlaciones
corr1 = df_analisis[cols_1].corr(method="spearman")
corr2 = df_analisis[cols_2].corr(method="spearman")

# Crear figura con dos paneles
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Matriz 1
sns.heatmap(
    corr1,
    annot=False,
    cmap="Oranges",
    vmin=-1, vmax=1,
    ax=axes[0]
)
axes[0].set_title("Correlaciones - Bloque 1")
axes[0].tick_params(axis='x', rotation=45)

# Matriz 2
sns.heatmap(
    corr2,
    annot=False,
    cmap="Greens",
    vmin=-1, vmax=1,
    ax=axes[1]
)
axes[1].set_title("Correlaciones - Bloque 2")
axes[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %%
# Miremos las funciones de distribución de nuestras variables

# %%
for col in cols_interest:
    plt.figure(figsize=(4,2))
    sns.histplot(df_analisis[col], bins=10, kde=False)
    plt.title(col)
    plt.show()

# %%
# Vamos a estadistica descriptiva directamente

# %%
df_analisis[cols_interest].describe()
# Out:
#             AP4_3_1       AP4_3_2       AP4_3_3      AP4_4_01      AP4_4_02  \
# count  90941.000000  90266.000000  89928.000000  91137.000000  62614.000000
# mean       1.372967      1.625983      1.727171      1.166102      1.244626
# std        0.483596      0.483871      0.445416      0.372174      0.429869
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        1.000000      1.000000      1.000000      1.000000      1.000000
# 50%        1.000000      2.000000      2.000000      1.000000      1.000000
# 75%        2.000000      2.000000      2.000000      1.000000      1.000000
# max        2.000000      2.000000      2.000000      2.000000      2.000000
#
#            AP4_4_03     AP4_4_04      AP4_4_05      AP4_4_06      AP4_4_07  \
# count  89673.000000  6764.000000  79798.000000  79911.000000  76459.000000
# mean       1.594159     1.325547      1.486867      1.387982      1.581750
# std        0.491057     0.468614      0.499831      0.487293      0.493275
# min        1.000000     1.000000      1.000000      1.000000      1.000000
# 25%        1.000000     1.000000      1.000000      1.000000      1.000000
# 50%        2.000000     1.000000      1.000000      1.000000      2.000000
# 75%        2.000000     2.000000      2.000000      2.000000      2.000000
# max        2.000000     2.000000      2.000000      2.000000      2.000000
#
#            AP4_4_08      AP4_4_09      AP4_4_10      AP4_4_11      AP4_4_12  \
# count  74824.000000  68342.000000  84823.000000  86540.000000  74537.000000
# mean       1.700631      1.597100      1.389918      1.614063      1.478031
# std        0.457985      0.490485      0.487734      0.486819      0.499520
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        1.000000      1.000000      1.000000      1.000000      1.000000
# 50%        2.000000      2.000000      1.000000      2.000000      1.000000
# 75%        2.000000      2.000000      2.000000      2.000000      2.000000
# max        2.000000      2.000000      2.000000      2.000000      2.000000
#
#             AP4_4_A
# count  84870.000000
# mean       2.661423
# std        0.796929
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.000000
# max        4.000000

# %%
df_analisis.groupby("SEXO")[cols_interest].mean() #Para cada variable calcula promedio de respuestas dentro de cada sexo
# Out:
#        AP4_3_1   AP4_3_2   AP4_3_3  AP4_4_01  AP4_4_02  AP4_4_03  AP4_4_04  \
# SEXO
# 1     1.322352  1.567978  1.672099  1.139514  1.224642  1.531631  1.284667
# 2     1.414483  1.673686  1.772412  1.187906  1.269049  1.645837  1.358130
#
#       AP4_4_05  AP4_4_06  AP4_4_07  AP4_4_08  AP4_4_09  AP4_4_10  AP4_4_11  \
# SEXO
# 1     1.411315  1.313704  1.500126  1.627868  1.523398  1.356889  1.558003
# 2     1.546954  1.449773  1.653321  1.764583  1.653761  1.417376  1.661133
#
#       AP4_4_12   AP4_4_A
# SEXO
# 1     1.399662  2.490982
# 2     1.545086  2.807331

# %%
df_analisis["grupo_edad"] = pd.cut(
    df_analisis["EDAD"],
    bins=[0, 29, 49, 100],
    labels=["Jóvenes", "Adultos", "Mayores"]
) # Comparamos por edad, para ello construimos los grupos 

df_analisis.groupby("grupo_edad")[cols_interest].mean()
# Out:
# C:\Users\Gaelj\AppData\Local\Temp\ipykernel_2676\1733638828.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_analisis.groupby("grupo_edad")[cols_interest].mean()
#              AP4_3_1   AP4_3_2   AP4_3_3  AP4_4_01  AP4_4_02  AP4_4_03  \
# grupo_edad
# Jóvenes     1.334347  1.602284  1.699679  1.101157  1.180733  1.598811
# Adultos     1.375052  1.634535  1.733319  1.169461  1.250000  1.628042
# Mayores     1.391750  1.630382  1.735992  1.198443  1.281509  1.555093
#
#             AP4_4_04  AP4_4_05  AP4_4_06  AP4_4_07  AP4_4_08  AP4_4_09  \
# grupo_edad
# Jóvenes     1.209569  1.455631  1.338429  1.520081  1.668723  1.602192
# Adultos     1.503635  1.513296  1.403155  1.609272  1.724938  1.618793
# Mayores     1.645161  1.475207  1.401348  1.589186  1.691509  1.568442
#
#             AP4_4_10  AP4_4_11  AP4_4_12   AP4_4_A
# grupo_edad
# Jóvenes     1.315653  1.577573  1.443957  2.653748
# Adultos     1.409661  1.641395  1.488953  2.656810
# Mayores     1.411482  1.605264  1.488970  2.670264

# %%
df_analisis["SEXO"].value_counts(normalize=True) * 100
# Out:
# SEXO
# 2    54.940668
# 1    45.059332
# Name: proportion, dtype: float64

# %%
### Ahora veamos que necesitamos para la segunda pregunta

# %%
# 2) ¿La confianza en las instituciones está asociada a la percepción de inseguridad?

# %%
# Definamos de vuelta que podemos necesitar para responder esto.
# Como en el caso anterior, la base TPer_Vic1 y podríamos también usar la base demográfica de TSDem
# Por lo tanto podemos seguir usando dfanalisis, lo único que va a cambiar van a ser las variables a usar

# %%
# En este caso nos va a servir AP5_4_01 a AP5_4_11 → confianza en cada autoridad (1=mucha confianza → 4=mucha desconfianza),AP5_5_01 a AP5_5_11 → si considera corrupta a cada autoridad (1=Sí, 2=No),
# AP5_5_01 a AP5_5_11 → si considera corrupta a cada autoridad (1=Sí, 2=No),
# AP5_6_01 a AP5_6_11 → qué tan efectiva considera a cada autoridad (1=muy efectivo → 4=nada efectivo).

# %%
# Para ello, vamos a usar el mismo dataframe que teniamos pero agregandole las varaibles de AP5_5 y AP5_6 dentro de ella

# %%
df_analisis.columns
# Out:
# Index(['Unnamed: 0', 'ID_VIV', 'ID_HOG', 'ID_PER', 'UPM', 'VIV_SEL', 'HOGAR',
#        'RESUL_H', 'R_SEL', 'AREAM',
#        ...
#        'FAC_ELE_AM', 'DOMINIO', 'ESTRATO', 'EST_DIS', 'UPM_DIS', 'N_REN',
#        'SEXO', 'EDAD', 'region', 'grupo_edad'],
#       dtype='object', length=244)

# %%
df_analisis[['AP5_4_01']].value_counts(dropna=False)
# Out:
# AP5_4_01
# NaN         32890
# 2.0         22469
# 3.0         17316
# 4.0         14221
# 1.0          3872
# 9.0           414
# Name: count, dtype: int64

# %%
df_analisis[['AP5_5_01']].value_counts(dropna=False)
# Out:
# AP5_5_01
# 1.0         42851
# NaN         32890
# 2.0         12562
# 9.0          2879
# Name: count, dtype: int64

# %%
df_analisis[['AP5_6_01']].value_counts(dropna=False)
# Out:
# AP5_6_01
# NaN         32890
# 3.0         22155
# 2.0         22117
# 4.0         10061
# 1.0          3413
# 9.0           546
# Name: count, dtype: int64

# %%
# Utilizando el diccionario podemos ver que tanto para el valor 9 como b, estos representan missing values al no haber respondido esa sección del cuestionario

# %%
cols_conf = [col for col in df_analisis.columns if col.startswith('AP5_4_')]
cols_corr = [col for col in df_analisis.columns if col.startswith('AP5_5_')]
cols_efec = [col for col in df_analisis.columns if col.startswith('AP5_6_')]

missing_values = ['b', 8, 9, 98, 99]

df_analisis[cols_conf + cols_corr + cols_efec] = df_analisis[cols_conf + cols_corr + cols_efec].replace(missing_values, np.nan)

# %%
df_analisis[['AP5_4_01']].value_counts(dropna=False)
# Out:
# AP5_4_01
# NaN         33304
# 2.0         22469
# 3.0         17316
# 4.0         14221
# 1.0          3872
# Name: count, dtype: int64

# %%
# Ahora si, como hicimos para la otra pregunta, hagamos toda la parte de estadística descriptiva

# %%
# Como la vez anterior, hagamos un heatmap de los missing values que tenemos acá

# %%
cols_total = cols_conf + cols_corr + cols_efec

# Calculamos el porcentaje de missing por variable
missing_pct = df_analisis[cols_total].isnull().mean() * 100

# Lo convertimos a DataFrame para el heatmap (una sola fila)
missing_df = pd.DataFrame(missing_pct).T

plt.figure(figsize=(20, 3))
ax = sns.heatmap(
    missing_df,
    annot=True,
    fmt=".1f",
    cmap="Greens",
    vmin=0,
    vmax=100,
    linewidths=0.5,
    cbar_kws={"label": "% Missing"}
)

# Etiqueta del eje Y
ax.set_yticklabels(["% Missing"], rotation=0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=9)

plt.title("Porcentaje de valores faltantes por variable")
plt.tight_layout()
plt.show()

# %%
# Miremos la función de distribución que siguen estás variables

# %%
for col in cols_total:
    plt.figure(figsize=(4,2))
    sns.histplot(df_analisis[col], bins=10, kde=False)
    plt.title(col)
    plt.show()

# %%
# Ahora hagamos la matriz de correlaciones

# %%
# Mirando la matriz de correlaciones completa, es decir con todas las variables dentro de ella:

# %%
corr = df_analisis[cols_total].corr()

plt.figure(figsize=(12,10))  # tamaño grande pero manejable
sns.heatmap(
    corr,
    cmap="coolwarm",
    vmin=-1, vmax=1,
    annot=False  # sin números
)
plt.title("Matriz de correlaciones completa")
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.yticks(rotation=0, fontsize=8)
plt.show()

# %%
# Ahora veamos dividiendo la matriz en dos de correlaciones y después ver la correlación entre esas dos

# %%
corr = df_analisis[cols_total].corr()

# Dividamos la matriz de correlaciones en dos 

mitad = len(cols_total) // 2

cols_1 = cols_total[:mitad]
cols_2 = cols_total[mitad:]

plt.figure(figsize=(10,8))
sns.heatmap(
    corr.loc[cols_1, cols_1],
    annot=False,
    fmt=".2f",
    cmap="coolwarm",
    vmin=-1, vmax=1  # MUY IMPORTANTE
)
plt.title("Matriz de correlaciones (Bloque 1)")
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.show()


plt.figure(figsize=(10,8))
sns.heatmap(
    corr.loc[cols_2, cols_2],
    annot=False,
    fmt=".2f",
    cmap="coolwarm",
    vmin=-1, vmax=1
)
plt.title("Matriz de correlaciones (Bloque 2)")
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.show()

# %%
# La correlación entre las dos matrices sería:

plt.figure(figsize=(10,8))
sns.heatmap(
    corr.loc[cols_1, cols_2],
    annot=False,
    fmt=".2f",
    cmap="coolwarm",
    vmin=-1, vmax=1
)
plt.title("Correlaciones entre variables de ambos bloques")
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.show()

# %%
# Pasemos a la estadistica descriptiva de estas variables:

# %%
desc = df_analisis[cols_total].describe().T

# Agregamos missing values
desc['missing'] = df_analisis[cols_total].isna().sum()
desc['missing_%'] = (desc['missing'] / len(df_analisis)) * 100

desc
# Out:
#             count      mean       std  min  25%  50%  75%  max  missing  \
# AP5_4_01  57878.0  2.723695  0.908398  1.0  2.0  3.0  3.0  4.0    33304
# AP5_4_02  52672.0  2.551356  0.884440  1.0  2.0  2.0  3.0  4.0    38510
# AP5_4_03  58810.0  2.486414  0.874728  1.0  2.0  2.0  3.0  4.0    32372
# AP5_4_04  70831.0  1.980235  0.825134  1.0  1.0  2.0  2.0  4.0    20351
# AP5_4_05  28739.0  2.437280  0.942455  1.0  2.0  2.0  3.0  4.0    62443
# AP5_4_06  29941.0  2.460973  0.911436  1.0  2.0  2.0  3.0  4.0    61241
# AP5_4_07  21212.0  2.341599  0.886378  1.0  2.0  2.0  3.0  4.0    69970
# AP5_4_08  74579.0  1.753456  0.774934  1.0  1.0  2.0  2.0  4.0    16603
# AP5_4_09  30553.0  1.622034  0.686372  1.0  1.0  2.0  2.0  4.0    60629
# AP5_4_10  55223.0  1.614671  0.703108  1.0  1.0  2.0  2.0  4.0    35959
# AP5_4_11  18129.0  2.468752  0.949652  1.0  2.0  2.0  3.0  4.0    73053
# AP5_5_01  55413.0  1.226698  0.418699  1.0  1.0  1.0  1.0  2.0    35769
# AP5_5_02  49511.0  1.312577  0.463548  1.0  1.0  1.0  2.0  2.0    41671
# AP5_5_03  55326.0  1.327459  0.469291  1.0  1.0  1.0  2.0  2.0    35856
# AP5_5_04  65928.0  1.644081  0.478794  1.0  1.0  2.0  2.0  2.0    25254
# AP5_5_05  27339.0  1.392699  0.488360  1.0  1.0  1.0  2.0  2.0    63843
# AP5_5_06  28635.0  1.352645  0.477802  1.0  1.0  1.0  2.0  2.0    62547
# AP5_5_07  20319.0  1.400955  0.490104  1.0  1.0  1.0  2.0  2.0    70863
# AP5_5_08  70508.0  1.722556  0.447740  1.0  1.0  2.0  2.0  2.0    20674
# AP5_5_09  29265.0  1.808167  0.393749  1.0  2.0  2.0  2.0  2.0    61917
# AP5_5_10  52756.0  1.788138  0.408632  1.0  2.0  2.0  2.0  2.0    38426
# AP5_5_11  17512.0  1.296254  0.456617  1.0  1.0  1.0  2.0  2.0    73670
# AP5_6_01  57746.0  2.673016  0.828699  1.0  2.0  3.0  3.0  4.0    33436
# AP5_6_02  52417.0  2.571093  0.826475  1.0  2.0  2.0  3.0  4.0    38765
# AP5_6_03  58540.0  2.480629  0.822074  1.0  2.0  2.0  3.0  4.0    32642
# AP5_6_04  70525.0  2.004098  0.805797  1.0  1.0  2.0  2.0  4.0    20657
# AP5_6_05  28691.0  2.403088  0.880708  1.0  2.0  2.0  3.0  4.0    62491
# AP5_6_06  29985.0  2.471769  0.865339  1.0  2.0  2.0  3.0  4.0    61197
# AP5_6_07  21275.0  2.360235  0.855147  1.0  2.0  2.0  3.0  4.0    69907
# AP5_6_08  74357.0  1.779631  0.763857  1.0  1.0  2.0  2.0  4.0    16825
# AP5_6_09  30789.0  1.671506  0.718173  1.0  1.0  2.0  2.0  4.0    60393
# AP5_6_10  55227.0  1.654951  0.723407  1.0  1.0  2.0  2.0  4.0    35955
# AP5_6_11  18138.0  2.436266  0.888155  1.0  2.0  2.0  3.0  4.0    73044
#
#           missing_%
# AP5_4_01  36.524753
# AP5_4_02  42.234213
# AP5_4_03  35.502621
# AP5_4_04  22.319098
# AP5_4_05  68.481718
# AP5_4_06  67.163475
# AP5_4_07  76.736637
# AP5_4_08  18.208638
# AP5_4_09  66.492290
# AP5_4_10  39.436512
# AP5_4_11  80.117786
# AP5_5_01  39.228137
# AP5_5_02  45.700906
# AP5_5_03  39.323551
# AP5_5_04  27.696256
# AP5_5_05  70.017109
# AP5_5_06  68.595775
# AP5_5_07  77.715997
# AP5_5_08  22.673335
# AP5_5_09  67.904850
# AP5_5_10  42.142089
# AP5_5_11  80.794455
# AP5_6_01  36.669518
# AP5_6_02  42.513873
# AP5_6_03  35.798732
# AP5_6_04  22.654691
# AP5_6_05  68.534360
# AP5_6_06  67.115220
# AP5_6_07  76.667544
# AP5_6_08  18.452107
# AP5_6_09  66.233467
# AP5_6_10  39.432125
# AP5_6_11  80.107916
