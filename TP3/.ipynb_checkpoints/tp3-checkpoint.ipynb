# %%
### Parte A:

# %%
#Importamos paquetes
import pandas as pd
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from scipy.stats import ttest_ind
from sklearn.model_selection import train_test_split

# %%
# Del tp anterior, importamos la base construida para lo pedido en ella.

# %%
os.chdir(r"C:\Users\Gaelj\OneDrive\Documentos\GitHub\E337_Grupo2\TP3")

# %%
ocupados1 = pd.read_csv("ocupados.csv")

# %%
ocupados2 = pd.read_csv("ocupados2.csv")
# Out:
# C:\Users\Gaelj\AppData\Local\Temp\ipykernel_16664\1476564008.py:1: DtypeWarning: Columns (0,12,102,105) have mixed types. Specify dtype option on import or set low_memory=False.
#   ocupados2 = pd.read_csv("ocupados2.csv")

# %%
ocupados3 = pd.read_csv("ocupados3.csv")
# Out:
# C:\Users\Gaelj\AppData\Local\Temp\ipykernel_16664\2394547012.py:1: DtypeWarning: Columns (0,12,102,105) have mixed types. Specify dtype option on import or set low_memory=False.
#   ocupados3 = pd.read_csv("ocupados3.csv")

# %%
ocupados1.columns
# Out:
# Index(['CH04', 'CH06', 'CH07', 'CH08', 'NIVEL_ED', 'ESTADO', 'CAT_INAC',
#        'IPCF', 'CH14', 'CH15_COD', 'CH16_COD', 'PP03C', 'PP04B_COD', 'PP06H',
#        'PP07A', 'AÑO', 'CAT_OCUP', 'PP07H', 'informal', 'EMPLEO', 'edad2',
#        'CH12', 'CH13', 'educ', 'ingreso_total_familiar', 'horastrab',
#        'ix_tot'],
#       dtype='object')

# %%
ocupados2.columns
# Out:
# Index(['CODUSU', 'ANO4', 'TRIMESTRE', 'NRO_HOGAR', 'COMPONENTE', 'H15',
#        'REGION', 'MAS_500', 'AGLOMERADO', 'PONDERA',
#        ...
#        'V21_M', 'PJ1_1', 'PJ2_1', 'PJ3_1', 'IDIMPP', 'ingreso_total_familiar',
#        'ingreso_total_familiar_mill', 'informal', 'horastrab', 'ix_tot'],
#       dtype='object', length=249)

# %%
ocupados3.columns
# Out:
# Index(['CODUSU', 'ANO4', 'TRIMESTRE', 'NRO_HOGAR', 'COMPONENTE', 'H15',
#        'REGION', 'MAS_500', 'AGLOMERADO', 'PONDERA',
#        ...
#        'AÑO', 'V2_M', 'V5_M', 'V11_M', 'V21_M', 'PJ1_1', 'PJ2_1', 'PJ3_1',
#        'IDIMPP', 'informal'],
#       dtype='object', length=245)

# %%
# Nosotros utilizamos varias bases para trabajar en disintas cosas, por lo que importamos todas para indentificar bien cuál sería la correcta a usar
# Viendo esto, usemos la base de ocupados2 que parece la más completa, pero agregemos la variable de edad y edad al cuadrado que no la tiene

# %%
ocupados = ocupados2.copy()

# %%
ocupados["edad2"] = ocupados["CH06"]**2

# %%
# Agregamos lo contruido en ocupados1 que es la variable educ que nos va a servir para más adelante

# %%
ocupados['educ'] = ocupados1['educ']

# %%
ocupados
# Out:
#                              CODUSU    ANO4  TRIMESTRE  NRO_HOGAR  COMPONENTE  \
# 0     TQRMNOTYPHKOKQCDEHNHB00867020  2025.0        3.0        1.0         8.0
# 1     TQRMNOTYPHKOKQCDEHNHB00867020  2025.0        3.0        1.0         9.0
# 2     TQRMNOTYPHKOKQCDEHNHB00867020  2025.0        3.0        1.0         1.0
# 3     TQRMNOTYPHKOKQCDEHNHB00867020  2025.0        3.0        1.0         2.0
# 4     TQRMNOTYPHKOKQCDEHNHB00867020  2025.0        3.0        1.0         3.0
# ...                             ...     ...        ...        ...         ...
# 9259                         287829  2005.0        3.0        1.0         2.0
# 9260                         287829  2005.0        3.0        1.0         3.0
# 9261                         287829  2005.0        3.0        1.0         4.0
# 9262                         287829  2005.0        3.0        1.0         5.0
# 9263                         287829  2005.0        3.0        1.0         6.0
#
#       H15  REGION MAS_500  AGLOMERADO  PONDERA  ...  PJ2_1  PJ3_1 IDIMPP  \
# 0     0.0    42.0       S        27.0    528.0  ...    NaN    NaN    NaN
# 1     0.0    42.0       S        27.0    528.0  ...    NaN    NaN    NaN
# 2     1.0    42.0       S        27.0    528.0  ...    NaN    NaN    NaN
# 3     1.0    42.0       S        27.0    528.0  ...    NaN    NaN    NaN
# 4     1.0    42.0       S        27.0    528.0  ...    NaN    NaN    NaN
# ...   ...     ...     ...         ...      ...  ...    ...    ...    ...
# 9259  1.0    42.0       N        27.0    227.0  ...    0.0    0.0    0.0
# 9260  0.0    42.0       N        27.0    227.0  ...    0.0    0.0    0.0
# 9261  0.0    42.0       N        27.0    227.0  ...    0.0    0.0    0.0
# 9262  0.0    42.0       N        27.0    227.0  ...    0.0    0.0    0.0
# 9263  1.0    42.0       N        27.0    227.0  ...    0.0    0.0    0.0
#
#       ingreso_total_familiar  ingreso_total_familiar_mill  informal  \
# 0                  1252000.0                      1.25200       NaN
# 1                  1252000.0                      1.25200       NaN
# 2                  1252000.0                      1.25200       NaN
# 3                  1252000.0                      1.25200       0.0
# 4                  1252000.0                      1.25200       NaN
# ...                      ...                          ...       ...
# 9259                711780.0                      0.71178       1.0
# 9260                711780.0                      0.71178       NaN
# 9261                711780.0                      0.71178       NaN
# 9262                711780.0                      0.71178       NaN
# 9263                711780.0                      0.71178       NaN
#
#       horastrab  ix_tot   edad2  educ
# 0           NaN       9    81.0   NaN
# 1           NaN       9     4.0  17.0
# 2           0.0       9  1444.0  17.0
# 3           NaN       9  1521.0   NaN
# 4           NaN       9   324.0   NaN
# ...         ...     ...     ...   ...
# 9259        NaN       6   529.0   NaN
# 9260        NaN       6    49.0   NaN
# 9261        NaN       6    25.0   NaN
# 9262        NaN       6     4.0   NaN
# 9263        NaN       6  5329.0   NaN
#
# [9264 rows x 251 columns]

# %%
### 1)

# %%
ocupados_2005 = ocupados[ocupados['AÑO'] == 2005]
ocupados_2025 = ocupados[ocupados['AÑO'] == 2025]

# %%
### 2)

# %%
# Variables predictoras
variables_x = [
    'CH06',
    'edad2',
    'educ',
    'ingreso_total_familiar',
    'horastrab',
    'ix_tot'
]

# Lista para resultados
resultados = []

for var in variables_x:
    x2005 = ocupados_2005[var].dropna()
    x2025 = ocupados_2025[var].dropna()

    media_2005 = x2005.mean()
    media_2025 = x2025.mean()
    diferencia = media_2025 - media_2005

    t_stat, p_value = ttest_ind(x2025, x2005, equal_var=False)

    resultados.append({
        'Variable': var,
        'Media 2005': media_2005,
        'Media 2025': media_2025,
        'Diferencia': diferencia,
        'p-value': p_value
    })

tabla_medias = pd.DataFrame(resultados)
tabla_medias
# Out:
# C:\Users\Gaelj\anaconda3\Lib\site-packages\scipy\_lib\deprecation.py:234: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return f(*args, **kwargs)
#                  Variable    Media 2005    Media 2025   Diferencia  \
# 0                    CH06  3.130269e+01  3.663681e+01     5.334116
# 1                   edad2  1.462081e+03  1.837150e+03   375.069465
# 2                    educ           NaN  1.188013e+01          NaN
# 3  ingreso_total_familiar  1.250504e+06  1.245069e+06 -5435.344359
# 4               horastrab  2.996461e+01  2.412725e+01    -5.837360
# 5                  ix_tot  4.702110e+00  3.884968e+00    -0.817142
#
#         p-value
# 0  6.488601e-31
# 1  1.247540e-23
# 2           NaN
# 3  8.313485e-01
# 4  4.925278e-10
# 5  7.886202e-86

# %%
# 3)

# %%
# Hagamos primero para la base de 2025

# %%
# La variable y va a estar definida por la variable que creamos en el tp anterior llamada "informal"
# El resto forma parte de las variables dependientes, es decir edad2, educ, ingreso_total_familiar, horastrab y ix_tot
# Construyamos primero eso entonces

# %%
# Guardemos primero las variables X relevantes solo para 2025

var_x = [
    'edad2',
    'educ',
    'ingreso_total_familiar',
    'horastrab',
    'ix_tot'
]

# Filtrar solamente las observaciones de 2025
ocupados_2025 = ocupados[ocupados['AÑO'] == 2025].copy()

# Crear la matriz X con solo esas variables
X_2025 = ocupados_2025[var_x].copy()

# %%
# Lo mismo vamos a hacer para 2005

# Filtrar solamente las observaciones de 2025
ocupados_2005 = ocupados[ocupados['AÑO'] == 2005].copy()

# Crear la matriz X con solo esas variables
X_2005 = ocupados_2005[var_x].copy()

# %%
X_2025
# Out:
#        edad2  educ  ingreso_total_familiar  horastrab  ix_tot
# 0       81.0   NaN               1252000.0        NaN       9
# 1        4.0  17.0               1252000.0        NaN       9
# 2     1444.0  17.0               1252000.0        0.0       9
# 3     1521.0   NaN               1252000.0        NaN       9
# 4      324.0   NaN               1252000.0        NaN       9
# ...      ...   ...                     ...        ...     ...
# 4472  1521.0   NaN               1260000.0        NaN       4
# 4473   361.0   NaN               1260000.0        NaN       4
# 4474   256.0   NaN               1260000.0        NaN       4
# 4475   625.0   NaN                200000.0        0.0       2
# 4476    36.0   NaN                200000.0        NaN       2
#
# [4477 rows x 5 columns]

# %%
X_2005
# Out:
#        edad2  educ  ingreso_total_familiar  horastrab  ix_tot
# 4477  2601.0   NaN               2372600.0       60.0       4
# 4478  2500.0   NaN               2372600.0        NaN       4
# 4479   529.0   NaN               2372600.0        NaN       4
# 4480   361.0   NaN               2372600.0        NaN       4
# 4481  1225.0   NaN                332164.0       46.0       4
# ...      ...   ...                     ...        ...     ...
# 9259   529.0   NaN                711780.0        NaN       6
# 9260    49.0   NaN                711780.0        NaN       6
# 9261    25.0   NaN                711780.0        NaN       6
# 9262     4.0   NaN                711780.0        NaN       6
# 9263  5329.0   NaN                711780.0        NaN       6
#
# [4787 rows x 5 columns]

# %%
# Ahora, guardemos también por separado la variable dependiente y:

y_2025 = ocupados_2025['informal'].copy()
y_2005= ocupados_2005['informal'].copy()

# %%
print(X_2025.shape)
print(y_2025.shape)

print(X_2005.shape)
print(y_2005.shape)
# Out:
# (4477, 5)
# (4477,)
# (4787, 5)
# (4787,)

# %%
# Con esto, deberíamos poder divir las muestras entre train y test con la función dada

# %%
X2025_train, X2025_test, y2025_train, y2025_test = train_test_split(X_2025, y_2025, test_size=0.70, random_state=444)

# %%
X2005_train, X2005_test, y2005_train, y2005_test = train_test_split(X_2005, y_2005, test_size=0.70, random_state=444)

# %%
# Me estaría faltando agregar la constante nada más

# %%
X2025_train['constante'] = 1

X2025_test['constante'] = 1

y2025_train['constante'] = 1

y2025_test['constante'] = 1

# %%
X2005_train['constante'] = 1

X2005_test['constante'] = 1

y2005_train['constante'] = 1

y2005_test['constante'] = 1

# %%
### Parte b
