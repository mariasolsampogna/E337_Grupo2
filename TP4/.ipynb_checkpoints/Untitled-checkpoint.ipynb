# %%
#Importamos paquetes
import pandas as pd
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
### TRABAJO PRÁCTICO N°4

# %%
# Antes de hacer cualquier cosa, corrijamos los errores que tuvimos a la hora de hacer el tp3

# %%
# Carguemos entonces la base pero desde el tp3 que ya la habiamos construido mejor.

# %%
os.chdir(r"C:\Users\Gaelj\OneDrive\Documentos\GitHub\E337_Grupo2\TP4")

# %%
ocupados = pd.read_csv('ocupados1.csv')

# %%
ocupados
# Out:
#       CH04  CH06  CH07  CH08  NIVEL_ED  ESTADO  CAT_INAC          IPCF  CH14  \
# 0      1.0  39.0   1.0   4.0       4.0     1.0       0.0  1.391111e+05   NaN
# 1      1.0  35.0   5.0   1.0       6.0     1.0       0.0  2.500000e+06   NaN
# 2      2.0  46.0   3.0   1.0       6.0     1.0       0.0  1.133333e+06   NaN
# 3      1.0  38.0   2.0   1.0       3.0     1.0       0.0  0.000000e+00  99.0
# 4      2.0  42.0   2.0   4.0       3.0     1.0       0.0  0.000000e+00  99.0
# ...    ...   ...   ...   ...       ...     ...       ...           ...   ...
# 3877   1.0  53.0   5.0   1.0       2.0     1.0       0.0  3.800000e+02   NaN
# 3878   1.0  52.0   2.0   4.0       2.0     1.0       0.0  1.533333e+02   NaN
# 3879   2.0  38.0   3.0  12.0       6.0     1.0       0.0  2.500000e+02   NaN
# 3880   1.0  28.0   2.0   4.0       2.0     1.0       0.0  1.250000e+02   NaN
# 3881   2.0  23.0   2.0   4.0       3.0     1.0       0.0  1.250000e+02   3.0
#
#       CH15_COD  ...  PP07H  informal  EMPLEO   edad2  CH12  CH13   educ  \
# 0          NaN  ...    0.0         0     2.0  1521.0   4.0   1.0   12.0
# 1          NaN  ...    2.0         1     2.0  1225.0   7.0   1.0   17.0
# 2          NaN  ...    1.0         0     1.0  2116.0   7.0   1.0   17.0
# 3          NaN  ...    1.0         0     1.0  1444.0   4.0   2.0  105.0
# 4          NaN  ...    2.0         1     2.0  1764.0   4.0   2.0  105.0
# ...        ...  ...    ...       ...     ...     ...   ...   ...    ...
# 3877       NaN  ...    1.0         0     NaN  2809.0   2.0   1.0    6.0
# 3878       NaN  ...    2.0         1     NaN  2704.0   2.0   1.0    6.0
# 3879       NaN  ...    1.0         0     NaN  1444.0   6.0   1.0   15.0
# 3880       NaN  ...    0.0         0     NaN   784.0   2.0   1.0    6.0
# 3881       NaN  ...    2.0         1     NaN   529.0   4.0   2.0    9.0
#
#       ingreso_total_familiar  horastrab  ix_tot
# 0                  1252000.0        NaN       9
# 1                  2500000.0       48.0       1
# 2                  3400000.0       45.0       3
# 3                        0.0       44.0      10
# 4                        0.0        NaN      10
# ...                      ...        ...     ...
# 3877               1081905.6        NaN       3
# 3878                436558.4      114.0       3
# 3879                474520.0       49.0       2
# 3880                711780.0        4.0       6
# 3881                711780.0        NaN       6
#
# [3882 rows x 27 columns]

# %%
# Ahora bien, para la construcción de la variable X nos habian pedido no solo con las variables que habiamos creado
# sino que era de manera general. Para ello debiamos seleccionar al menos 15 de ellas y justificar porque creiamos que podrian serlo

# %%
# Que Y sea la variable informal estaba bien, en eso no habia problemas. Pensemos ahora mirando el dicionario
# cuales nos pueden servir para la matriz X.

# %%
#
